# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Slicing and Dicing

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)
#
# Start by creating and connecting to the database by running the cells below.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql
# Out:
# createdb: database creation failed: ERROR:  database "pagila_star" already exists
#  set_config
# ------------
#
# (1 row)
#
# psql:Data/pagila-star.sql:42: ERROR:  type "mpaa_rating" already exists
# psql:Data/pagila-star.sql:52: ERROR:  type "year" already exists
# psql:Data/pagila-star.sql:69: ERROR:  function "_group_concat" already exists with same argument types
# psql:Data/pagila-star.sql:86: ERROR:  function "film_in_stock" already exists with same argument types
# psql:Data/pagila-star.sql:103: ERROR:  function "film_not_in_stock" already exists with same argument types
# psql:Data/pagila-star.sql:148: ERROR:  function "get_customer_balance" already exists with same argument types
# psql:Data/pagila-star.sql:170: ERROR:  function "inventory_held_by_customer" already exists with same argument types
# psql:Data/pagila-star.sql:207: ERROR:  function "inventory_in_stock" already exists with same argument types
# psql:Data/pagila-star.sql:225: ERROR:  function "last_day" already exists with same argument types
# psql:Data/pagila-star.sql:240: ERROR:  function "last_updated" already exists with same argument types
# psql:Data/pagila-star.sql:264: ERROR:  relation "customer" already exists
# psql:Data/pagila-star.sql:328: ERROR:  function "rewards_report" already exists with same argument types
# psql:Data/pagila-star.sql:340: ERROR:  function "group_concat" already exists with same argument types
# psql:Data/pagila-star.sql:354: ERROR:  relation "actor_actor_id_seq" already exists
# psql:Data/pagila-star.sql:368: ERROR:  relation "actor" already exists
# psql:Data/pagila-star.sql:382: ERROR:  relation "category_category_id_seq" already exists
# psql:Data/pagila-star.sql:395: ERROR:  relation "category" already exists
# psql:Data/pagila-star.sql:409: ERROR:  relation "film_film_id_seq" already exists
# psql:Data/pagila-star.sql:433: ERROR:  relation "film" already exists
# psql:Data/pagila-star.sql:446: ERROR:  relation "film_actor" already exists
# psql:Data/pagila-star.sql:459: ERROR:  relation "film_category" already exists
# psql:Data/pagila-star.sql:482: ERROR:  relation "actor_info" already exists
# psql:Data/pagila-star.sql:496: ERROR:  relation "address_address_id_seq" already exists
# psql:Data/pagila-star.sql:514: ERROR:  relation "address" already exists
# psql:Data/pagila-star.sql:528: ERROR:  relation "city_city_id_seq" already exists
# psql:Data/pagila-star.sql:542: ERROR:  relation "city" already exists
# psql:Data/pagila-star.sql:556: ERROR:  relation "country_country_id_seq" already exists
# psql:Data/pagila-star.sql:569: ERROR:  relation "country" already exists
# psql:Data/pagila-star.sql:583: ERROR:  relation "customer_customer_id_seq" already exists
# psql:Data/pagila-star.sql:597: ERROR:  relation "customer_customer_id_seq1" already exists
# psql:Data/pagila-star.sql:629: ERROR:  relation "customer_list" already exists
# psql:Data/pagila-star.sql:655: ERROR:  relation "dimcustomer" already exists
# psql:Data/pagila-star.sql:669: ERROR:  relation "dimcustomer_customer_key_seq" already exists
# psql:Data/pagila-star.sql:694: ERROR:  relation "dimdate" already exists
# psql:Data/pagila-star.sql:715: ERROR:  relation "dimmovie" already exists
# psql:Data/pagila-star.sql:729: ERROR:  relation "dimmovie_movie_key_seq" already exists
# psql:Data/pagila-star.sql:758: ERROR:  relation "dimstore" already exists
# psql:Data/pagila-star.sql:772: ERROR:  relation "dimstore_store_key_seq" already exists
# psql:Data/pagila-star.sql:795: ERROR:  relation "factsales" already exists
# psql:Data/pagila-star.sql:809: ERROR:  relation "factsales_sales_key_seq" already exists
# psql:Data/pagila-star.sql:839: ERROR:  relation "film_list" already exists
# psql:Data/pagila-star.sql:853: ERROR:  relation "inventory_inventory_id_seq" already exists
# psql:Data/pagila-star.sql:867: ERROR:  relation "inventory" already exists
# psql:Data/pagila-star.sql:881: ERROR:  relation "language_language_id_seq" already exists
# psql:Data/pagila-star.sql:894: ERROR:  relation "language" already exists
# psql:Data/pagila-star.sql:917: ERROR:  relation "nicer_but_slower_film_list" already exists
# psql:Data/pagila-star.sql:931: ERROR:  relation "payment_payment_id_seq" already exists
# psql:Data/pagila-star.sql:947: ERROR:  relation "payment" already exists
# psql:Data/pagila-star.sql:961: ERROR:  relation "rental_rental_id_seq" already exists
# psql:Data/pagila-star.sql:978: ERROR:  relation "rental" already exists
# psql:Data/pagila-star.sql:997: ERROR:  relation "sales_by_film_category" already exists
# psql:Data/pagila-star.sql:1011: ERROR:  relation "staff_staff_id_seq" already exists
# psql:Data/pagila-star.sql:1032: ERROR:  relation "staff" already exists
# psql:Data/pagila-star.sql:1046: ERROR:  relation "store_store_id_seq" already exists
# psql:Data/pagila-star.sql:1060: ERROR:  relation "store" already exists
# psql:Data/pagila-star.sql:1082: ERROR:  relation "sales_by_store" already exists
# psql:Data/pagila-star.sql:1103: ERROR:  relation "staff_list" already exists
# psql:Data/pagila-star.sql:1360: ERROR:  duplicate key value violates unique constraint "actor_pkey"
# DETAIL:  Key (actor_id)=(1) already exists.
# CONTEXT:  COPY actor, line 1
#  setval
# --------
#     200
# (1 row)
#
# psql:Data/pagila-star.sql:1978: ERROR:  duplicate key value violates unique constraint "address_pkey"
# DETAIL:  Key (address_id)=(1) already exists.
# CONTEXT:  COPY address, line 1
#  setval
# --------
#     605
# (1 row)
#
# psql:Data/pagila-star.sql:2009: ERROR:  duplicate key value violates unique constraint "category_pkey"
# DETAIL:  Key (category_id)=(1) already exists.
# CONTEXT:  COPY category, line 1
#  setval
# --------
#      16
# (1 row)
#
# psql:Data/pagila-star.sql:2624: ERROR:  duplicate key value violates unique constraint "city_pkey"
# DETAIL:  Key (city_id)=(1) already exists.
# CONTEXT:  COPY city, line 1
#  setval
# --------
#     600
# (1 row)
#
# psql:Data/pagila-star.sql:2748: ERROR:  duplicate key value violates unique constraint "country_pkey"
# DETAIL:  Key (country_id)=(1) already exists.
# CONTEXT:  COPY country, line 1
#  setval
# --------
#     109
# (1 row)
#
# psql:Data/pagila-star.sql:3362: ERROR:  duplicate key value violates unique constraint "customer_pkey"
# DETAIL:  Key (customer_id)=(1) already exists.
# CONTEXT:  COPY customer, line 1
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:3983: ERROR:  duplicate key value violates unique constraint "dimcustomer_pkey"
# DETAIL:  Key (customer_key)=(1) already exists.
# CONTEXT:  COPY dimcustomer, line 1
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:4038: ERROR:  duplicate key value violates unique constraint "dimdate_pkey"
# DETAIL:  Key (date_key)=(20170407) already exists.
# CONTEXT:  COPY dimdate, line 1
# psql:Data/pagila-star.sql:5046: ERROR:  duplicate key value violates unique constraint "dimmovie_pkey"
# DETAIL:  Key (movie_key)=(1) already exists.
# CONTEXT:  COPY dimmovie, line 1
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:5063: ERROR:  duplicate key value violates unique constraint "dimstore_pkey"
# DETAIL:  Key (store_key)=(1) already exists.
# CONTEXT:  COPY dimstore, line 1
#  setval
# --------
#       1
# (1 row)
#
# psql:Data/pagila-star.sql:37176: ERROR:  duplicate key value violates unique constraint "factsales_pkey"
# DETAIL:  Key (sales_key)=(1) already exists.
# CONTEXT:  COPY factsales, line 1
#  setval
# --------
#   32098
# (1 row)
#
# psql:Data/pagila-star.sql:38191: ERROR:  duplicate key value violates unique constraint "film_pkey"
# DETAIL:  Key (film_id)=(1) already exists.
# CONTEXT:  COPY film, line 1: "1	ACADEMY DINOSAUR	A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The C..."
# psql:Data/pagila-star.sql:43661: ERROR:  duplicate key value violates unique constraint "film_actor_pkey"
# DETAIL:  Key (actor_id, film_id)=(1, 1) already exists.
# CONTEXT:  COPY film_actor, line 1
# psql:Data/pagila-star.sql:44669: ERROR:  duplicate key value violates unique constraint "film_category_pkey"
# DETAIL:  Key (film_id, category_id)=(1, 6) already exists.
# CONTEXT:  COPY film_category, line 1
#  setval
# --------
#    1000
# (1 row)
#
# psql:Data/pagila-star.sql:49265: ERROR:  duplicate key value violates unique constraint "inventory_pkey"
# DETAIL:  Key (inventory_id)=(1) already exists.
# CONTEXT:  COPY inventory, line 1
#  setval
# --------
#    4581
# (1 row)
#
# psql:Data/pagila-star.sql:49286: ERROR:  duplicate key value violates unique constraint "language_pkey"
# DETAIL:  Key (language_id)=(1) already exists.
# CONTEXT:  COPY language, line 1
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
# psql:Data/pagila-star.sql:129556: ERROR:  duplicate key value violates unique constraint "rental_pkey"
# DETAIL:  Key (rental_id)=(2) already exists.
# CONTEXT:  COPY rental, line 1
#  setval
# --------
#   16049
# (1 row)
#
# psql:Data/pagila-star.sql:129573: ERROR:  duplicate key value violates unique constraint "staff_pkey"
# DETAIL:  Key (staff_id)=(1) already exists.
# CONTEXT:  COPY staff, line 1
#  setval
# --------
#       2
# (1 row)
#
# psql:Data/pagila-star.sql:129590: ERROR:  duplicate key value violates unique constraint "store_pkey"
# DETAIL:  Key (store_id)=(1) already exists.
# CONTEXT:  COPY store, line 1
#  setval
# --------
#       2
# (1 row)
#
# psql:Data/pagila-star.sql:145662: ERROR:  multiple primary keys for table "actor" are not allowed
# psql:Data/pagila-star.sql:145670: ERROR:  multiple primary keys for table "address" are not allowed
# psql:Data/pagila-star.sql:145678: ERROR:  multiple primary keys for table "category" are not allowed
# psql:Data/pagila-star.sql:145686: ERROR:  multiple primary keys for table "city" are not allowed
# psql:Data/pagila-star.sql:145694: ERROR:  multiple primary keys for table "country" are not allowed
# psql:Data/pagila-star.sql:145702: ERROR:  multiple primary keys for table "customer" are not allowed
# psql:Data/pagila-star.sql:145710: ERROR:  multiple primary keys for table "dimcustomer" are not allowed
# psql:Data/pagila-star.sql:145718: ERROR:  multiple primary keys for table "dimdate" are not allowed
# psql:Data/pagila-star.sql:145726: ERROR:  multiple primary keys for table "dimmovie" are not allowed
# psql:Data/pagila-star.sql:145734: ERROR:  multiple primary keys for table "dimstore" are not allowed
# psql:Data/pagila-star.sql:145742: ERROR:  multiple primary keys for table "factsales" are not allowed
# psql:Data/pagila-star.sql:145750: ERROR:  multiple primary keys for table "film_actor" are not allowed
# psql:Data/pagila-star.sql:145758: ERROR:  multiple primary keys for table "film_category" are not allowed
# psql:Data/pagila-star.sql:145766: ERROR:  multiple primary keys for table "film" are not allowed
# psql:Data/pagila-star.sql:145774: ERROR:  multiple primary keys for table "inventory" are not allowed
# psql:Data/pagila-star.sql:145782: ERROR:  multiple primary keys for table "language" are not allowed
# psql:Data/pagila-star.sql:145790: ERROR:  multiple primary keys for table "rental" are not allowed
# psql:Data/pagila-star.sql:145798: ERROR:  multiple primary keys for table "staff" are not allowed
# psql:Data/pagila-star.sql:145806: ERROR:  multiple primary keys for table "store" are not allowed
# psql:Data/pagila-star.sql:145813: ERROR:  relation "film_fulltext_idx" already exists
# psql:Data/pagila-star.sql:145820: ERROR:  relation "idx_actor_last_name" already exists
# psql:Data/pagila-star.sql:145827: ERROR:  relation "idx_fk_address_id" already exists
# psql:Data/pagila-star.sql:145834: ERROR:  relation "idx_fk_city_id" already exists
# psql:Data/pagila-star.sql:145841: ERROR:  relation "idx_fk_country_id" already exists
# psql:Data/pagila-star.sql:145848: ERROR:  relation "idx_fk_customer_id" already exists
# psql:Data/pagila-star.sql:145855: ERROR:  relation "idx_fk_film_id" already exists
# psql:Data/pagila-star.sql:145862: ERROR:  relation "idx_fk_inventory_id" already exists
# psql:Data/pagila-star.sql:145869: ERROR:  relation "idx_fk_language_id" already exists
# psql:Data/pagila-star.sql:145876: ERROR:  relation "idx_fk_original_language_id" already exists
# psql:Data/pagila-star.sql:145883: ERROR:  relation "idx_fk_payment_customer_id" already exists
# psql:Data/pagila-star.sql:145890: ERROR:  relation "idx_fk_payment_staff_id" already exists
# psql:Data/pagila-star.sql:145897: ERROR:  relation "idx_fk_store_id" already exists
# psql:Data/pagila-star.sql:145904: ERROR:  relation "idx_last_name" already exists
# psql:Data/pagila-star.sql:145911: ERROR:  relation "idx_store_id_film_id" already exists
# psql:Data/pagila-star.sql:145918: ERROR:  relation "idx_title" already exists
# psql:Data/pagila-star.sql:145925: ERROR:  relation "idx_unq_manager_staff_id" already exists
# psql:Data/pagila-star.sql:145932: ERROR:  relation "idx_unq_rental_rental_date_inventory_id_customer_id" already exists
# psql:Data/pagila-star.sql:145939: ERROR:  trigger "film_fulltext_trigger" for relation "film" already exists
# psql:Data/pagila-star.sql:145946: ERROR:  trigger "last_updated" for relation "actor" already exists
# psql:Data/pagila-star.sql:145953: ERROR:  trigger "last_updated" for relation "address" already exists
# psql:Data/pagila-star.sql:145960: ERROR:  trigger "last_updated" for relation "category" already exists
# psql:Data/pagila-star.sql:145967: ERROR:  trigger "last_updated" for relation "city" already exists
# psql:Data/pagila-star.sql:145974: ERROR:  trigger "last_updated" for relation "country" already exists
# psql:Data/pagila-star.sql:145981: ERROR:  trigger "last_updated" for relation "customer" already exists
# psql:Data/pagila-star.sql:145988: ERROR:  trigger "last_updated" for relation "film" already exists
# psql:Data/pagila-star.sql:145995: ERROR:  trigger "last_updated" for relation "film_actor" already exists
# psql:Data/pagila-star.sql:146002: ERROR:  trigger "last_updated" for relation "film_category" already exists
# psql:Data/pagila-star.sql:146009: ERROR:  trigger "last_updated" for relation "inventory" already exists
# psql:Data/pagila-star.sql:146016: ERROR:  trigger "last_updated" for relation "language" already exists
# psql:Data/pagila-star.sql:146023: ERROR:  trigger "last_updated" for relation "rental" already exists
# psql:Data/pagila-star.sql:146030: ERROR:  trigger "last_updated" for relation "staff" already exists
# psql:Data/pagila-star.sql:146037: ERROR:  trigger "last_updated" for relation "store" already exists
# psql:Data/pagila-star.sql:146045: ERROR:  constraint "address_city_id_fkey" for relation "address" already exists
# psql:Data/pagila-star.sql:146053: ERROR:  constraint "city_country_id_fkey" for relation "city" already exists
# psql:Data/pagila-star.sql:146061: ERROR:  constraint "customer_address_id_fkey" for relation "customer" already exists
# psql:Data/pagila-star.sql:146069: ERROR:  constraint "customer_store_id_fkey" for relation "customer" already exists
# psql:Data/pagila-star.sql:146077: ERROR:  constraint "factsales_customer_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:146085: ERROR:  constraint "factsales_date_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:146093: ERROR:  constraint "factsales_movie_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:146101: ERROR:  constraint "factsales_store_key_fkey" for relation "factsales" already exists
# psql:Data/pagila-star.sql:146109: ERROR:  constraint "film_actor_actor_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-star.sql:146117: ERROR:  constraint "film_actor_film_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-star.sql:146125: ERROR:  constraint "film_category_category_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-star.sql:146133: ERROR:  constraint "film_category_film_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-star.sql:146141: ERROR:  constraint "film_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-star.sql:146149: ERROR:  constraint "film_original_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-star.sql:146157: ERROR:  constraint "inventory_film_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-star.sql:146165: ERROR:  constraint "inventory_store_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-star.sql:146173: ERROR:  constraint "payment_customer_id_fkey" for relation "payment" already exists
# psql:Data/pagila-star.sql:146181: ERROR:  constraint "payment_rental_id_fkey" for relation "payment" already exists
# psql:Data/pagila-star.sql:146189: ERROR:  constraint "payment_staff_id_fkey" for relation "payment" already exists
# psql:Data/pagila-star.sql:146197: ERROR:  constraint "rental_customer_id_fkey" for relation "rental" already exists
# psql:Data/pagila-star.sql:146205: ERROR:  constraint "rental_inventory_id_fkey" for relation "rental" already exists
# psql:Data/pagila-star.sql:146213: ERROR:  constraint "rental_staff_id_fkey" for relation "rental" already exists
# psql:Data/pagila-star.sql:146221: ERROR:  constraint "staff_address_id_fkey" for relation "staff" already exists
# psql:Data/pagila-star.sql:146229: ERROR:  constraint "staff_store_id_fkey" for relation "staff" already exists
# psql:Data/pagila-star.sql:146237: ERROR:  constraint "store_address_id_fkey" for relation "store" already exists

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Start with a simple cube
# TODO: Write a query that calculates the revenue (sales_amount) by day, rating, and city. Remember to join with the appropriate dimension tables to replace the keys with the dimension labels. Sort by revenue in descending order and limit to the first 20 rows. The first few rows of your output should match the table below.

# %%
# %%time
# %%sql
SELECT t.day, m.rating, s.city, sum(f.sales_amount) as revenue
FROM factsales f 
JOIN dimdate t ON (f.date_key = t.date_key)
JOIN dimmovie m ON (f.movie_key = m.movie_key)
JOIN dimstore s ON (f.store_key = s.store_key)
GROUP BY t.day, m.rating, s.city
ORDER BY  revenue desc
LIMIT 20
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 20 rows affected.
# CPU times: user 4.99 ms, sys: 251 µs, total: 5.25 ms
# Wall time: 25.3 ms
# [(30, 'PG-13', 'Lethbridge', Decimal('784.21')),
#  (30, 'G', 'Lethbridge', Decimal('730.48')),
#  (30, 'R', 'Lethbridge', Decimal('683.46')),
#  (30, 'NC-17', 'Woodridge', Decimal('667.49')),
#  (30, 'NC-17', 'Lethbridge', Decimal('646.51')),
#  (30, 'PG-13', 'Woodridge', Decimal('635.48')),
#  (30, 'PG', 'Woodridge', Decimal('593.57')),
#  (30, 'G', 'Woodridge', Decimal('587.58')),
#  (20, 'PG-13', 'Lethbridge', Decimal('538.93')),
#  (30, 'PG', 'Lethbridge', Decimal('521.78')),
#  (21, 'PG-13', 'Lethbridge', Decimal('499.92')),
#  (30, 'R', 'Woodridge', Decimal('495.74')),
#  (17, 'PG-13', 'Woodridge', Decimal('488.83')),
#  (18, 'R', 'Woodridge', Decimal('472.95')),
#  (18, 'PG-13', 'Lethbridge', Decimal('466.92')),
#  (19, 'PG-13', 'Lethbridge', Decimal('465.87')),
#  (19, 'NC-17', 'Woodridge', Decimal('456.98')),
#  (28, 'PG-13', 'Lethbridge', Decimal('455.97')),
#  (21, 'NC-17', 'Lethbridge', Decimal('451.95')),
#  (18, 'NC-17', 'Lethbridge', Decimal('447.01'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>G</td>
#         <td>San Bernardino</td>
#         <td>24.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>NC-17</td>
#         <td>Apeldoorn</td>
#         <td>23.95</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>NC-17</td>
#         <td>Belm</td>
#         <td>22.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Zanzibar</td>
#         <td>21.97</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>R</td>
#         <td>Mwanza</td>
#         <td>21.97</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Slicing
#
# Slicing is the reduction of the dimensionality of a cube by 1 e.g. 3 dimensions to 2, fixing one of the dimensions to a single value. In the example above, we have a 3-dimensional cube on day, rating, and country.
#
# TODO: Write a query that reduces the dimensionality of the above example by limiting the results to only include movies with a `rating` of "PG-13". Again, sort by revenue in descending order and limit to the first 20 rows. The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT t.day, m.rating, s.city, sum(f.sales_amount) as revenue
FROM factsales f 
JOIN dimdate t ON (f.date_key = t.date_key)
JOIN dimmovie m ON (f.movie_key = m.movie_key)
JOIN dimstore s ON (f.store_key = s.store_key)
WHERE m.rating = 'PG-13'
GROUP BY t.day, m.rating, s.city
ORDER BY  revenue desc
LIMIT 20;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 20 rows affected.
# CPU times: user 4.85 ms, sys: 217 µs, total: 5.06 ms
# Wall time: 12.8 ms
# [(30, 'PG-13', 'Lethbridge', Decimal('784.21')),
#  (30, 'PG-13', 'Woodridge', Decimal('635.48')),
#  (20, 'PG-13', 'Lethbridge', Decimal('538.93')),
#  (21, 'PG-13', 'Lethbridge', Decimal('499.92')),
#  (17, 'PG-13', 'Woodridge', Decimal('488.83')),
#  (18, 'PG-13', 'Lethbridge', Decimal('466.92')),
#  (19, 'PG-13', 'Lethbridge', Decimal('465.87')),
#  (28, 'PG-13', 'Lethbridge', Decimal('455.97')),
#  (27, 'PG-13', 'Woodridge', Decimal('444.90')),
#  (19, 'PG-13', 'Woodridge', Decimal('430.01')),
#  (18, 'PG-13', 'Woodridge', Decimal('428.93')),
#  (29, 'PG-13', 'Lethbridge', Decimal('414.09')),
#  (21, 'PG-13', 'Woodridge', Decimal('391.05')),
#  (27, 'PG-13', 'Lethbridge', Decimal('374.14')),
#  (28, 'PG-13', 'Woodridge', Decimal('368.12')),
#  (17, 'PG-13', 'Lethbridge', Decimal('368.09')),
#  (20, 'PG-13', 'Woodridge', Decimal('362.00')),
#  (22, 'PG-13', 'Lethbridge', Decimal('347.18')),
#  (29, 'PG-13', 'Woodridge', Decimal('326.18')),
#  (1, 'PG-13', 'Lethbridge', Decimal('310.30'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Zanzibar</td>
#         <td>21.97</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>PG-13</td>
#         <td>Dhaka</td>
#         <td>19.97</td>
#     </tr>
#     <tr>
#         <td>29</td>
#         <td>PG-13</td>
#         <td>Shimoga</td>
#         <td>18.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Osmaniye</td>
#         <td>18.97</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>PG-13</td>
#         <td>Asuncin</td>
#         <td>18.95</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Dicing
# Dicing is creating a subcube with the same dimensionality but fewer values for  two or more dimensions.
#
# TODO: Write a query to create a subcube of the initial cube that includes moves with:
# * ratings of PG or PG-13
# * in the city of Bellevue or Lancaster
# * day equal to 1, 15, or 30
#
# The first few rows of your output should match the table below.

# %%
# %%time
# %%sql


SELECT t.day, m.rating, s.city, sum(f.sales_amount) as revenue
FROM factsales f 
JOIN dimdate t ON (f.date_key = t.date_key)
JOIN dimmovie m ON (f.movie_key = m.movie_key)
JOIN dimstore s ON (f.store_key = s.store_key)
WHERE m.rating in ('PG-13', 'PG') 
AND s.city in ('Lethbridge', 'Woodridge') 
AND t.day in ('1', '15', '30')
GROUP BY t.day, m.rating, s.city
ORDER BY  revenue desc
LIMIT 20;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 12 rows affected.
# CPU times: user 6.33 ms, sys: 0 ns, total: 6.33 ms
# Wall time: 11.4 ms
# [(30, 'PG-13', 'Lethbridge', Decimal('784.21')),
#  (30, 'PG-13', 'Woodridge', Decimal('635.48')),
#  (30, 'PG', 'Woodridge', Decimal('593.57')),
#  (30, 'PG', 'Lethbridge', Decimal('521.78')),
#  (1, 'PG', 'Woodridge', Decimal('316.16')),
#  (1, 'PG-13', 'Lethbridge', Decimal('310.30')),
#  (1, 'PG-13', 'Woodridge', Decimal('306.30')),
#  (1, 'PG', 'Lethbridge', Decimal('296.30')),
#  (15, 'PG-13', 'Woodridge', Decimal('195.54')),
#  (15, 'PG-13', 'Lethbridge', Decimal('151.61')),
#  (15, 'PG', 'Lethbridge', Decimal('140.65')),
#  (15, 'PG', 'Woodridge', Decimal('138.66'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG</td>
#         <td>Lancaster</td>
#         <td>12.98</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>PG-13</td>
#         <td>Lancaster</td>
#         <td>5.99</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Bellevue</td>
#         <td>3.99</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Lancaster</td>
#         <td>2.99</td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>PG-13</td>
#         <td>Bellevue</td>
#         <td>1.98</td>
#     </tr>
# </tbody></table></div>
